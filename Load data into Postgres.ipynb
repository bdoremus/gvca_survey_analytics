# %%
INPUT_FILEPATH = '/Users/bendoremus/Downloads/2022 Parent Satisfaction Survey (partial results).csv'
DATABASE_SCHEMA = 'sac_survey_2022'

# %%
import pandas as pd

from csv import reader as csv_reader
from sqlalchemy import create_engine, text
from pprint import pprint

# %%
eng = create_engine('postgresql://bendoremus:@localhost:5432/gvca')
with eng.connect():
    pass
# Out:
# WARNING: password file "/Users/bendoremus/.pgpass" has group or world access; permissions should be u=rw (0600) or less

# %%
df = pd.read_csv(INPUT_FILEPATH)
df.head(3).T
# Out:
#                                                                                                     0  \
# Respondent ID                                                                                     NaN
# Collector ID                                                                                      NaN
# Start Date                                                                                        NaN
# End Date                                                                                          NaN
# IP Address                                                                                        NaN
# Email Address                                                                                     NaN
# First Name                                                                                        NaN
# Last Name                                                                                         NaN
# Custom Data 1                                                                                     NaN
# How many years have you had a child at Golden V...                                Open-Ended Response
# Did you or one of your children attend conferen...                                     Grammar School
# Unnamed: 11                                                                              Upper School
# Given your children’s education level at the be...                                     Grammar School
# Unnamed: 13                                                                              Upper School
# How satisfied are you with the education that y...                                     Grammar School
# Unnamed: 15                                                                              Upper School
# GVCA emphasizes 7 core virtues: Courage, Modera...                                     Grammar School
# Unnamed: 17                                                                              Upper School
# How effective is the communication between your...                                     Grammar School
# Unnamed: 19                                                                              Upper School
# How effective is the communication between your...                                           Response
# How welcoming is the school community?                                                 Grammar School
# Unnamed: 22                                                                              Upper School
# Given this year's challenges, what are your tho...                                           Teachers
# Unnamed: 24                                                                         School Leadership
# Unnamed: 25                                                                          Student Services
# Unnamed: 26                                                                Your Children's well-being
# What makes GVCA a good choice for you and your ...                      Both Grammar and Upper School
# Unnamed: 28                                                                            Grammar School
# Unnamed: 29                                                                              Upper School
# Please provide us with examples of how GVCA can...                      Both Grammar and Upper School
# Unnamed: 31                                                                            Grammar School
# Unnamed: 32                                                                              Upper School
# What services have your children received at Go...   Qualify for Economic Assistance - Grammar School
# Unnamed: 34                                            Qualify for Economic Assistance - Upper School
# Unnamed: 35                                         IEP and related services, including Resource C...
# Unnamed: 36                                         IEP and related services, including Resource C...
# Unnamed: 37                                         Section 504 Plan and related services - Gramma...
# Unnamed: 38                                         Section 504 Plan and related services - Upper ...
# Unnamed: 39                                         Gifted and Talented Programming/Advanced Learn...
# Unnamed: 40                                         Gifted and Talented Programming/Advanced Learn...
# Unnamed: 41                                         English Language Learning Services - Grammar S...
# Unnamed: 42                                         English Language Learning Services - Upper School
# Unnamed: 43                                                     Reading Intervention - Grammar School
# Unnamed: 44                                                       Reading Intervention - Upper School
# Unnamed: 45                                                        Math Intervention - Grammar School
# Unnamed: 46                                                          Math Intervention - Upper School
# Unnamed: 47                                         Student Behavior/ Counseling-type services - G...
# Unnamed: 48                                         Student Behavior/ Counseling-type services - U...
# Unnamed: 49                                                                    Other - Grammar School
# Unnamed: 50                                                                      Other - Upper School
# Unnamed: 51                                         If other, please specify which services and wh...
# Do you consider yourself or your children part ...                                           Response
#
#                                                                                                     1  \
# Respondent ID                                                                           13345599422.0
# Collector ID                                                                              414834425.0
# Start Date                                                                     02/20/2022 07:15:17 PM
# End Date                                                                       02/20/2022 07:24:44 PM
# IP Address                                                                                        NaN
# Email Address                                                                                     NaN
# First Name                                                                                        NaN
# Last Name                                                                                         NaN
# Custom Data 1                                                                                     NaN
# How many years have you had a child at Golden V...                                                  4
# Did you or one of your children attend conferen...                                                Yes
# Unnamed: 11                                                                                       Yes
# Given your children’s education level at the be...                                Extremely Satisfied
# Unnamed: 13                                                                                 Satisfied
# How satisfied are you with the education that y...                                Extremely Satisfied
# Unnamed: 15                                                                                 Satisfied
# GVCA emphasizes 7 core virtues: Courage, Modera...                                         Influenced
# Unnamed: 17                                                                                Influenced
# How effective is the communication between your...                                          Effective
# Unnamed: 19                                                                                 Effective
# How effective is the communication between your...                                          Effective
# How welcoming is the school community?                                                      Welcoming
# Unnamed: 22                                                                        Somewhat Welcoming
# Given this year's challenges, what are your tho...                                             strong
# Unnamed: 24                                                                                    strong
# Unnamed: 25                                         lacking- needs stronger support/additional sta...
# Unnamed: 26                                         depends on the situation- overall the school v...
# What makes GVCA a good choice for you and your ...                                  strong academics
# Unnamed: 28                                                                         strong academics
# Unnamed: 29                                                      meets and accommodates the IEP needs
# Please provide us with examples of how GVCA can...  more options for clubs and extra curricular ac...
# Unnamed: 31                                                                                       NaN
# Unnamed: 32                                              drama- bring back the option to be in a play
# What services have your children received at Go...                                                NaN
# Unnamed: 34                                                                                       NaN
# Unnamed: 35                                                                                       NaN
# Unnamed: 36                                                                              Upper School
# Unnamed: 37                                                                                       NaN
# Unnamed: 38                                                                                       NaN
# Unnamed: 39                                                                                       NaN
# Unnamed: 40                                                                                       NaN
# Unnamed: 41                                                                                       NaN
# Unnamed: 42                                                                                       NaN
# Unnamed: 43                                                                                       NaN
# Unnamed: 44                                                                                       NaN
# Unnamed: 45                                                                                       NaN
# Unnamed: 46                                                                              Upper School
# Unnamed: 47                                                                                       NaN
# Unnamed: 48                                                                                       NaN
# Unnamed: 49                                                                                       NaN
# Unnamed: 50                                                                                       NaN
# Unnamed: 51                                                                                       NaN
# Do you consider yourself or your children part ...                                                 No
#
#                                                                                                     2
# Respondent ID                                                                           13344905413.0
# Collector ID                                                                              414834425.0
# Start Date                                                                     02/20/2022 09:05:46 AM
# End Date                                                                       02/20/2022 09:13:19 AM
# IP Address                                                                                        NaN
# Email Address                                                                                     NaN
# First Name                                                                                        NaN
# Last Name                                                                                         NaN
# Custom Data 1                                                                                     NaN
# How many years have you had a child at Golden V...                                                  6
# Did you or one of your children attend conferen...                                                NaN
# Unnamed: 11                                                                                       Yes
# Given your children’s education level at the be...                                                NaN
# Unnamed: 13                                                                        Somewhat Satisfied
# How satisfied are you with the education that y...                                                NaN
# Unnamed: 15                                                                        Somewhat Satisfied
# GVCA emphasizes 7 core virtues: Courage, Modera...                                                NaN
# Unnamed: 17                                                                       Somewhat influenced
# How effective is the communication between your...                                                NaN
# Unnamed: 19                                                                                 Effective
# How effective is the communication between your...                                          Effective
# How welcoming is the school community?                                                            NaN
# Unnamed: 22                                                                                 Welcoming
# Given this year's challenges, what are your tho...  Good teachers who care about education, but so...
# Unnamed: 24                                                              Too wrapped up in politics
# Unnamed: 25                                                            Good support on post-grad life
# Unnamed: 26                                         Overall good, but am displeased with his Covid...
# What makes GVCA a good choice for you and your ...                                                NaN
# Unnamed: 28                                                                                       NaN
# Unnamed: 29                                         It is rigorous and is a place where students a...
# Please provide us with examples of how GVCA can...                                                NaN
# Unnamed: 31                                                                                       NaN
# Unnamed: 32                                         The school should have a bit more options for ...
# What services have your children received at Go...                                                NaN
# Unnamed: 34                                                                                       NaN
# Unnamed: 35                                                                                       NaN
# Unnamed: 36                                                                                       NaN
# Unnamed: 37                                                                                       NaN
# Unnamed: 38                                                                                       NaN
# Unnamed: 39                                                                                       NaN
# Unnamed: 40                                                                                       NaN
# Unnamed: 41                                                                                       NaN
# Unnamed: 42                                                                                       NaN
# Unnamed: 43                                                                                       NaN
# Unnamed: 44                                                                                       NaN
# Unnamed: 45                                                                                       NaN
# Unnamed: 46                                                                                       NaN
# Unnamed: 47                                                                                       NaN
# Unnamed: 48                                                                                       NaN
# Unnamed: 49                                                                                       NaN
# Unnamed: 50                                                                                       NaN
# Unnamed: 51                                                                                       NaN
# Do you consider yourself or your children part ...                                                 No

# %%
df['Unnamed: 15'].value_counts()
# Out:
# Extremely Satisfied    40
# Satisfied              17
# Somewhat Satisfied      8
# Not Satisfied           2
# Upper School            1
# Name: Unnamed: 15, dtype: int64

# %%
# get headers, organize columns
with open(INPUT_FILEPATH, 'r') as f_in:
    raw_data_reader = csv_reader(f_in)
    raw_header = raw_data_reader.__next__()
    raw_sub_header = raw_data_reader.__next__()
    ignore_sub_headers = ['Open-Ended Response', 'Response']
    
    # fill empty columns with the appropriate question
    questions = []
    for i, (question, sub_question) in enumerate(zip(raw_header, raw_sub_header)):
        questions += [(i,
                       (question if question else questions[-1][1]),
                       (sub_question if sub_question and sub_question not in ignore_sub_headers else None))]
    
pprint(questions)
# Out:
# [(0, 'Respondent ID', None),
#  (1, 'Collector ID', None),
#  (2, 'Start Date', None),
#  (3, 'End Date', None),
#  (4, 'IP Address', None),
#  (5, 'Email Address', None),
#  (6, 'First Name', None),
#  (7, 'Last Name', None),
#  (8, 'Custom Data 1', None),
#  (9,
#   'How many years have you had a child at Golden View Classical Academy?  The '
#   'current academic year counts as 1.',
#   None),
#  (10,
#   'Did you or one of your children attend conferences this year?',
#   'Grammar School'),
#  (11,
#   'Did you or one of your children attend conferences this year?',
#   'Upper School'),
#  (12,
#   'Given your children’s education level at the beginning of of the year, how '
#   'satisfied are you with their intellectual growth this year?',
#   'Grammar School'),
#  (13,
#   'Given your children’s education level at the beginning of of the year, how '
#   'satisfied are you with their intellectual growth this year?',
#   'Upper School'),
#  (14,
#   'How satisfied are you with the education that your children have received '
#   'at Golden View Classical Academy this year?',
#   'Grammar School'),
#  (15,
#   'How satisfied are you with the education that your children have received '
#   'at Golden View Classical Academy this year?',
#   'Upper School'),
#  (16,
#   'GVCA emphasizes 7 core virtues: Courage, Moderation, Justice, '
#   'Responsibility, Prudence, Friendship, and Wonder. How strongly is the '
#   'school culture influenced by those virtues?',
#   'Grammar School'),
#  (17,
#   'GVCA emphasizes 7 core virtues: Courage, Moderation, Justice, '
#   'Responsibility, Prudence, Friendship, and Wonder. How strongly is the '
#   'school culture influenced by those virtues?',
#   'Upper School'),
#  (18,
#   "How effective is the communication between your family and your childrens' "
#   'teachers?',
#   'Grammar School'),
#  (19,
#   "How effective is the communication between your family and your childrens' "
#   'teachers?',
#   'Upper School'),
#  (20,
#   'How effective is the communication between your family and the school '
#   'leadership?',
#   None),
#  (21, 'How welcoming is the school community?', 'Grammar School'),
#  (22, 'How welcoming is the school community?', 'Upper School'),
#  (23,
#   "Given this year's challenges, what are your thoughts on the following "
#   'aspects of the school environment?',
#   'Teachers'),
#  (24,
#   "Given this year's challenges, what are your thoughts on the following "
#   'aspects of the school environment?',
#   'School Leadership'),
#  (25,
#   "Given this year's challenges, what are your thoughts on the following "
#   'aspects of the school environment?',
#   'Student Services'),
#  (26,
#   "Given this year's challenges, what are your thoughts on the following "
#   'aspects of the school environment?',
#   "Your Children's well-being"),
#  (27,
#   'What makes GVCA a good choice for you and your family?',
#   'Both Grammar and Upper School'),
#  (28,
#   'What makes GVCA a good choice for you and your family?',
#   'Grammar School'),
#  (29, 'What makes GVCA a good choice for you and your family?', 'Upper School'),
#  (30,
#   'Please provide us with examples of how GVCA can better serve you and your '
#   'family.',
#   'Both Grammar and Upper School'),
#  (31,
#   'Please provide us with examples of how GVCA can better serve you and your '
#   'family.',
#   'Grammar School'),
#  (32,
#   'Please provide us with examples of how GVCA can better serve you and your '
#   'family.',
#   'Upper School'),
#  (33,
#   'What services have your children received at Golden View this school year? '
#   'Please check all that apply.',
#   'Qualify for Economic Assistance - Grammar School'),
#  (34,
#   'What services have your children received at Golden View this school year? '
#   'Please check all that apply.',
#   'Qualify for Economic Assistance - Upper School'),
#  (35,
#   'What services have your children received at Golden View this school year? '
#   'Please check all that apply.',
#   'IEP and related services, including Resource Class, Psychological services, '
#   'Speech/Language services, and Occupational therapy services - Grammar '
#   'School'),
#  (36,
#   'What services have your children received at Golden View this school year? '
#   'Please check all that apply.',
#   'IEP and related services, including Resource Class, Psychological services, '
#   'Speech/Language services, and Occupational therapy services - Upper School'),
#  (37,
#   'What services have your children received at Golden View this school year? '
#   'Please check all that apply.',
#   'Section 504 Plan and related services - Grammar School'),
#  (38,
#   'What services have your children received at Golden View this school year? '
#   'Please check all that apply.',
#   'Section 504 Plan and related services - Upper School'),
#  (39,
#   'What services have your children received at Golden View this school year? '
#   'Please check all that apply.',
#   'Gifted and Talented Programming/Advanced Learning Plans - Grammar School'),
#  (40,
#   'What services have your children received at Golden View this school year? '
#   'Please check all that apply.',
#   'Gifted and Talented Programming/Advanced Learning Plans - Upper School'),
#  (41,
#   'What services have your children received at Golden View this school year? '
#   'Please check all that apply.',
#   'English Language Learning Services - Grammar School'),
#  (42,
#   'What services have your children received at Golden View this school year? '
#   'Please check all that apply.',
#   'English Language Learning Services - Upper School'),
#  (43,
#   'What services have your children received at Golden View this school year? '
#   'Please check all that apply.',
#   'Reading Intervention - Grammar School'),
#  (44,
#   'What services have your children received at Golden View this school year? '
#   'Please check all that apply.',
#   'Reading Intervention - Upper School'),
#  (45,
#   'What services have your children received at Golden View this school year? '
#   'Please check all that apply.',
#   'Math Intervention - Grammar School'),
#  (46,
#   'What services have your children received at Golden View this school year? '
#   'Please check all that apply.',
#   'Math Intervention - Upper School'),
#  (47,
#   'What services have your children received at Golden View this school year? '
#   'Please check all that apply.',
#   'Student Behavior/ Counseling-type services - Grammar School'),
#  (48,
#   'What services have your children received at Golden View this school year? '
#   'Please check all that apply.',
#   'Student Behavior/ Counseling-type services - Upper School'),
#  (49,
#   'What services have your children received at Golden View this school year? '
#   'Please check all that apply.',
#   'Other - Grammar School'),
#  (50,
#   'What services have your children received at Golden View this school year? '
#   'Please check all that apply.',
#   'Other - Upper School'),
#  (51,
#   'What services have your children received at Golden View this school year? '
#   'Please check all that apply.',
#   'If other, please specify which services and whether it was for your Upper '
#   'or Grammar school children.'),
#  (52,
#   'Do you consider yourself or your children part of a racial, ethnic, or '
#   'cultural minority group?',
#   None)]

# %%
# use the output above to relate each column to a question
{
    0: 'respondent_id',
    1: 'collector_id',
    2: 'start_datetime',
    3: 'end_datetime',
    9: (1, 'Tenure at GVCA in years', None),
    10: (2, 'Conference Attendence', 'Grammar'),
    11: (2, 'Conference Attendence', 'Upper'),
    12: (3, 'Intellectual Growth', 'Grammar'),
    13: (3, 'Intellectual Growth', 'Upper'),
    14: (4, 'Education Received', 'Grammar'),
    15: (4, 'Education Received', 'Upper'),
    16: (5, 'Virtues', 'Grammar'),
    17: (5, 'Virtues', 'Upper'),
    18: (6, 'Teacher Communication', 'Grammar'),
    19: (6, 'Teacher Communication', 'Upper'),
    20: (7, 'Leadership Communication', None),
    21: (8, 'Community welcoming', 'Grammar'),
    22: (8, 'Community welcoming', 'Upper'),
    23: (9, "This year's challenges: Teachers", None),
    24: (9, "This year's challenges: Leadership", None),
    25: (9, "This year's challenges: Student Services", None),
    26: (9, "This year's challenges: Child", None),
    27: (10, "Why good choice", "Both"),
    28: (10, "Why good choice", "Grammar"),
    29: (10, "Why good choice", "Upper"),
    30: (11, "Improve", "Both"),
    31: (11, "Improve", "Grammar"),
    32: (11, "Improve", "Upper"),
    33: (12, "Services provided: Economic Assistance", "Grammar"),
    34: (12, "Services provided: Economic Assistance", "Upper"),
    35: (12, "Services provided: IEP", "Grammar"),
    36: (12, "Services provided: IEP", "Upper"),
    37: (12, "Services provided: 504", "Grammar"),
    38: (12, "Services provided: 504", "Upper"),
    39: (12, "Services provided: Gifted", "Grammar"),
    40: (12, "Services provided: Gifted", "Upper"),
    41: (12, "Services provided: Language", "Grammar"),
    42: (12, "Services provided: Language", "Upper"),
    43: (12, "Services provided: Reading", "Grammar"),
    44: (12, "Services provided: Reading", "Upper"),
    45: (12, "Services provided: Math", "Grammar"),
    46: (12, "Services provided: Math", "Upper"),
    47: (12, "Services provided: Behavior", "Grammar"),
    48: (12, "Services provided: Behavior", "Upper"),
    49: (12, "Services provided: Other", "Grammar"),
    50: (12, "Services provided: Other", "Upper"),
    51: (12, "Services provided: Description of Other", "Read text for context"),
    52: (13, "Minority", None),
}
pass

# %%
# functions for writing to postgres
def add_to_table(conn, tablename, **kwargs):
    keys = kwargs.keys()
    query = text(
        f'INSERT INTO {tablename} ({", ".join(list(keys))}) '
        f'VALUES ({", ".join([":"+k for k in keys])})'
    )
    conn.execute(query, {**{'tablename': tablename}, **kwargs})
    
    
def split_grammar_upper_rank(conn, question_id, grammar_response, upper_response, **kwargs):
    tablename = 'question_rank'
    if grammar_response:
        # add response
        add_to_table(
            conn=conn, 
            tablename=tablename,
            question_id=question_id,
            grammar=True,
            upper=False,
            response=convert_to_int(grammar_response),
            **kwargs
        )
    if upper_response:
        # add response
        add_to_table(
            conn=conn, 
            tablename=tablename,
            question_id=question_id,
            grammar=False,
            upper=True,
            response=convert_to_int(upper_response),
            **kwargs
        )
        

def open_response_question(conn, sub_questions_and_responses, **kwargs):
    for sub_question_id, response in sub_questions_and_responses.items():
        if response:
            add_to_table(
                conn,
                tablename='question_open_response',
                sub_question_id=sub_question_id,
                response=response,
                **kwargs
            )
            
            
def add_services(conn, grammar_services, upper_services, other_description, **kwargs):
    for k, v in grammar_services.items():
        if v:
            add_to_table(
                conn,
                tablename='question_services_provided',
                grammar=True,
                upper=False,
                service_name=k,
                **kwargs,
            )
    for k, v in upper_services.items():
        if v:
            add_to_table(
                conn,
                tablename='question_services_provided',
                grammar=False,
                upper=True,
                service_name=k,
                **kwargs,
            )
    if other_description:
        add_to_table(
                conn,
                tablename='question_services_provided',
                grammar=False,
                upper=False,
                service_name=f'OTHER DESCRIPTION: {other_description}',
                **kwargs,
            )


def convert_to_bool(value):
    return True if value == 'Yes' else False if value == 'No' else None

def convert_to_int(value):
    if value.startswith('Extremely') or value.startswith('Strongly'):
        return 4
    if value.startswith('Somewhat'):
        return 2
    if value.startswith('Not'):
        return 1
    return 3

# %%
with open(INPUT_FILEPATH, 'r') as f_in, eng.connect() as conn:
    raw_data_reader = csv_reader(f_in)
    
    # skip the first two rows
    raw_header = raw_data_reader.__next__()
    raw_sub_header = raw_data_reader.__next__()
    
    conn.execute('BEGIN TRANSACTION;')
    conn.execute(f"SET SCHEMA '{DATABASE_SCHEMA}'")
    
    # TODO: Remove before pushing to prod!
    conn.execute(f'TRUNCATE respondents CASCADE;')
    
    for row in raw_data_reader:
        # respondents, includes demographics and question 1
        add_to_table(
            conn,
            tablename='respondents',
            respondent_id=row[0],
            collector_id=row[1],
            start_datetime=row[2],
            end_datetime=row[3],
            tenure=convert_to_int(row[9]),
            grammar_conferences=convert_to_bool(row[10]),
            upper_conferences=convert_to_bool(row[11]),
            grammar_support=any(row[33:51:2]),
            upper_support=any(row[34:51:2]),
            any_support=any(row[34:52]),
            minority=convert_to_bool(row[52]),
        )
        
        # question 3:
        # Given your children’s education level at the beginning of of the year, how satisfied are you with their intellectual growth this year?
        split_grammar_upper_rank(
            conn,
            question_id='3',
            respondent_id=row[0],
            grammar_response=row[12],
            upper_response=row[13],
        )
        
        # question 4:
        # How satisfied are you with the education that your children have received at Golden View Classical Academy this year?	
        split_grammar_upper_rank(
            conn,
            question_id='4',
            respondent_id=row[0],
            grammar_response=row[14],
            upper_response=row[15],
        )
        
        # question 5:
        # GVCA emphasizes 7 core virtues: Courage, Moderation, Justice, Responsibility, Prudence, Friendship, and Wonder. How strongly is the school culture influenced by those virtues?
        split_grammar_upper_rank(
            conn,
            question_id='5',
            respondent_id=row[0],
            grammar_response=row[16],
            upper_response=row[17],
        )
        
        # question 6:
        # How effective is the communication between your family and your childrens' teachers?
        split_grammar_upper_rank(
            conn,
            question_id='6',
            respondent_id=row[0],
            grammar_response=row[18],
            upper_response=row[19],
        )
        
        # question 7:
        # How effective is the communication between your family and the school leadership?	
        if row[20]:
            add_to_table(
                conn,
                tablename='question_rank',
                respondent_id=row[0],
                question_id='7',
                grammar=False,
                upper=False,
                response=convert_to_int(row[20]),
            )
        
        # question 8:
        # How welcoming is the school community?
        split_grammar_upper_rank(
            conn,
            question_id='8',
            respondent_id=row[0],
            grammar_response=row[21],
            upper_response=row[22],
        )
        
        # question 9:
        # Given this year's challenges, what are your thoughts on the following aspects of the school environment?
        open_response_question(
            conn,
            sub_questions_and_responses={
                'teacher': row[23],
                'leadership': row[24],
                'student_services': row[25],
                'child': row[26],
            },
            respondent_id=row[0],
            question_id='9',
        )
        
        # question 10:
        # What makes GVCA a good choice for you and your family?
        open_response_question(
            conn,
            sub_questions_and_responses={
                'both': row[27],
                'grammar': row[28],
                'upper': row[29],
            },
            respondent_id=row[0],
            question_id='10',       
        )
        
        # question 11:
        # Please provide us with examples of how GVCA can better serve you and your family.
        open_response_question(
            conn,
            sub_questions_and_responses={
                'both': row[30],
                'grammar': row[31],
                'upper': row[32],
            },
            respondent_id=row[0],
            question_id='11',
        )
        
        # question 12:
        # What services have your children received at Golden View this school year? Please check all that apply.
        add_services(
            conn,
            respondent_id=row[0],
            question_id='12',
            grammar_services={
                'Qualify for Economic Assistance': row[33],
                'IEP and related services, including Resource Class, Psychological services, Speech/Lanugage services, and Occupational therapy services': row[35],
                'Section 504 Plan and related services': row[37],
                'Gifted and Talented Programming/Advanced Learning Plans': row[39],
                'English Language Learning Services': row[41],
                'Reading Intervention': row[43],
                'Math Intervention': row[45],
                'Student Behavior/Counseling-type services': row[47],
                'Other': row[49],
            },
            upper_services={
                'Qualify for Economic Assistance': row[34],
                'IEP and related services, including Resource Class, Psychological services, Speech/Lanugage services, and Occupational therapy services': row[36],
                'Section 504 Plan and related services': row[38],
                'Gifted and Talented Programming/Advanced Learning Plans': row[40],
                'English Language Learning Services': row[41],
                'Reading Intervention': row[44],
                'Math Intervention': row[46],
                'Student Behavior/Counseling-type services': row[48],
                'Other': row[50],
            },
            other_description=row[51],
        )

    conn.execute('END TRANSACTION;')
